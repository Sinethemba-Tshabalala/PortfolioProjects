# %% [markdown]
# # Automating Crypto Website API Pull

# %% [markdown]
# ### Copy and pasting code from API and running it in order to be able to use API key

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '846ab453-f4e2-4d5f-823a-7f152027c87b',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %% [markdown]
# ### Importing pandas to use to nomalize data

# %%
import pandas as pd

pd.set_option('display.max.rows', None)

# %%
pd.json_normalize(data['data'])
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7779
# 2     825  Tether USDt   USDT        tether             65686
# 3    1839          BNB    BNB           bnb              1759
# 4      52          XRP    XRP           xrp              1141
# 5    3408         USDC   USDC      usd-coin             14925
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               972
# 8      74     Dogecoin   DOGE      dogecoin               825
# 9    1958         TRON    TRX          tron               869
# 10   3890      Polygon  MATIC       polygon              1066
# 11   1975    Chainlink   LINK     chainlink              1430
# 12  11419      Toncoin    TON       toncoin               171
# 13   6636     Polkadot    DOT  polkadot-new               612
# 14   5805    Avalanche   AVAX     avalanche               553
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2019-04-28T00:00:00.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2021-08-26T13:40:22.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...                NaN
# 10  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
# 11  [platform, defi, oracles, smart-contracts, sub...   1000000000.00000
# 12  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                NaN
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19542118.00000     19542118.00000            False       NaN
# 1      120257710.74970    120257710.74970             True       NaN
# 2    87077275102.70656  90623656719.71295             True       NaN
# 3      151701394.36130    151701394.36130            False       NaN
# 4    53652766196.00000  99988240531.00000            False       NaN
# 5    23997451492.01001  23997451492.01001            False       NaN
# 6      422396770.12951    562465267.60190             True       NaN
# 7    35271148839.05000  36350273102.30800            False       NaN
# 8   141826936383.70526 141826936383.70526             True       NaN
# 9    88673717334.78125  88673741439.88318             True       NaN
# 10    9250379771.02586  10000000000.00000            False       NaN
# 11     556849970.45279   1000000000.00000            False       NaN
# 12    3431892087.62000   5047558528.00000             True       NaN
# 13    1245285817.60842   1377546319.31678             True       NaN
# 14     355446829.06767    432823009.06767            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          7                               NaN                       NaN
# 6          6                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                 71659659264.00000          7614743987.76288
# 10        11                               NaN                       NaN
# 11        12                               NaN                       NaN
# 12        13                  3414166606.00000          8057274527.56762
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-11-14T14:32:00.000Z      36562.33387     19886476615.01379
# 1       None  2023-11-14T14:32:00.000Z       2046.71428     13467566714.05680
# 2       None  2023-11-14T14:30:00.000Z          1.00038     46410958646.71170
# 3       None  2023-11-14T14:30:00.000Z        245.68482       925653084.79613
# 4       None  2023-11-14T14:32:00.000Z          0.66214      3548594961.59591
# 5       None  2023-11-14T14:31:00.000Z          1.00001      5732123230.15776
# 6       None  2023-11-14T14:31:00.000Z         56.70324      3238094724.21505
# 7       None  2023-11-14T14:30:00.000Z          0.36748       431690340.01191
# 8       None  2023-11-14T14:32:00.000Z          0.07488       748191594.04702
# 9       None  2023-11-14T14:30:00.000Z          0.10626       283175482.02243
# 10      None  2023-11-14T14:31:00.000Z          0.91889      1392653920.22450
# 11      None  2023-11-14T14:30:00.000Z         14.64114       912284672.56658
# 12      None  2023-11-14T14:31:00.000Z          2.35995        43446688.27669
# 13      None  2023-11-14T14:30:00.000Z          5.43208       295631974.11415
# 14      None  2023-11-14T14:30:00.000Z         17.64455       809349356.20836
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      36.27190                     -0.18307
# 1                      33.12830                     -0.13641
# 2                      23.29040                      0.00783
# 3                      19.60730                      0.63223
# 4                     245.04300                      0.88051
# 5                      31.94890                      0.00139
# 6                      32.82070                      6.08451
# 7                      16.04390                      2.17689
# 8                      13.09030                      1.15367
# 9                       8.45700                      0.81886
# 10                     47.46740                     -0.94718
# 11                     16.91970                      2.54098
# 12                    -22.58980                      0.71961
# 13                     -8.09880                      1.63750
# 14                     -7.73680                      4.87209
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -0.80438                      5.13051
# 1                       -1.16403                      9.13210
# 2                        0.00779                     -0.01399
# 3                       -0.26164                     -0.58188
# 4                        1.49875                     -2.74447
# 5                       -0.00449                     -0.00764
# 6                       -2.44976                     35.67657
# 7                       -0.91531                      6.21562
# 8                       -3.85345                      1.84278
# 9                       -3.47806                      9.84162
# 10                       4.11401                     28.52097
# 11                      -3.94498                     13.39477
# 12                      -3.28195                     -3.72711
# 13                      -2.92332                     11.02314
# 14                       0.53674                     38.61208
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       35.87266                      38.77508
# 1                       31.55929                      26.43374
# 2                        0.02822                       0.02970
# 3                       17.55955                      15.96844
# 4                       36.03133                      34.48702
# 5                       -0.00851                       0.00075
# 6                      160.02120                     199.91167
# 7                       49.35983                      48.09212
# 8                       26.36780                      21.27422
# 9                       24.28402                      27.88816
# 10                      78.18881                      77.07020
# 11                      99.80891                     137.82253
# 12                      22.42229                      20.00024
# 13                      45.05187                      32.72925
# 14                      93.32484                      90.27395
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       25.64255    714505442809.87341
# 1                       12.27413    246133174039.54776
# 2                        0.15094     87110706717.42296
# 3                        5.35815     37270729922.38690
# 4                       11.37844     35525833453.97668
# 5                       -0.00298     23997794423.31768
# 6                      144.75830     23951267533.23141
# 7                       34.29984     12961425112.99809
# 8                        8.12620     10620442959.74155
# 9                       40.45987      9422702576.07586
# 10                      47.43280      8500119126.58939
# 11                     114.10776      8152917784.90563
# 12                      63.55946      8099105840.45514
# 13                      14.65581      6764491823.38085
# 14                      53.35215      6271699588.57755
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         51.02010                  767809011234.46997
# 1                         17.56480                  246133174039.54999
# 2                          6.22040                   90658449898.21001
# 3                          2.65790                   37270729922.39000
# 4                          2.53520                   66214355703.85000
# 5                          1.71260                   23997794423.32000
# 6                          1.70920                   31893605858.66000
# 7                          0.92560                   16536578741.64000
# 8                          0.75710                   10620442959.74000
# 9                          0.67200                    9422705137.55000
# 10                         0.60620                    9188940710.54000
# 11                         0.58220                   14641138937.79000
# 12                         0.57800                   11912003556.77000
# 13                         0.48240                    7482941411.19000
# 14                         0.44760                   12704076487.67000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-11-14T14:32:00.000Z          NaN           NaN
# 1           None  2023-11-14T14:32:00.000Z          NaN           NaN
# 2           None  2023-11-14T14:30:00.000Z   1027.00000      Ethereum
# 3           None  2023-11-14T14:30:00.000Z          NaN           NaN
# 4           None  2023-11-14T14:32:00.000Z          NaN           NaN
# 5           None  2023-11-14T14:31:00.000Z   1027.00000      Ethereum
# 6           None  2023-11-14T14:31:00.000Z          NaN           NaN
# 7           None  2023-11-14T14:30:00.000Z          NaN           NaN
# 8           None  2023-11-14T14:32:00.000Z          NaN           NaN
# 9           None  2023-11-14T14:30:00.000Z          NaN           NaN
# 10          None  2023-11-14T14:31:00.000Z          NaN           NaN
# 11          None  2023-11-14T14:30:00.000Z   1027.00000      Ethereum
# 12          None  2023-11-14T14:31:00.000Z          NaN           NaN
# 13          None  2023-11-14T14:30:00.000Z          NaN           NaN
# 14          None  2023-11-14T14:30:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN

# %% [markdown]
# ### Assigning the normalized data to dataframe variable 'df'

# %%
df = pd.json_normalize(data['data'])

# %% [markdown]
# ### Creating a 'timestamp' column to show the time and date the code runs

# %%
df['timestamp'] = pd.to_datetime('now')

df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             10552
# 1    1027     Ethereum    ETH      ethereum              7778
# 2     825  Tether USDt   USDT        tether             65679
# 3    1839          BNB    BNB           bnb              1759
# 4      52          XRP    XRP           xrp              1141
# 5    3408         USDC   USDC      usd-coin             14922
# 6    5426       Solana    SOL        solana               546
# 7    2010      Cardano    ADA       cardano               972
# 8      74     Dogecoin   DOGE      dogecoin               825
# 9    1958         TRON    TRX          tron               869
# 10   3890      Polygon  MATIC       polygon              1066
# 11  11419      Toncoin    TON       toncoin               171
# 12   1975    Chainlink   LINK     chainlink              1430
# 13   6636     Polkadot    DOT  polkadot-new               612
# 14   5805    Avalanche   AVAX     avalanche               553
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2013-08-04T00:00:00.000Z
# 5   2018-10-08T00:00:00.000Z
# 6   2020-04-10T00:00:00.000Z
# 7   2017-10-01T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-09-13T00:00:00.000Z
# 10  2019-04-28T00:00:00.000Z
# 11  2021-08-26T13:40:22.000Z
# 12  2017-09-20T00:00:00.000Z
# 13  2020-08-19T00:00:00.000Z
# 14  2020-07-13T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 5   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 6   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 7   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [media, payments, tron-ecosystem, dwf-labs-por...                NaN
# 10  [pos, platform, enterprise-solutions, zero-kno...  10000000000.00000
# 11  [pos, ftx-bankruptcy-estate, dwf-labs-portfoli...                NaN
# 12  [platform, defi, oracles, smart-contracts, sub...   1000000000.00000
# 13  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 14  [defi, smart-contracts, three-arrows-capital-p...    720000000.00000
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19542068.00000     19542068.00000            False       NaN
# 1      120257710.74970    120257710.74970             True       NaN
# 2    87077275102.70656  90623656719.71295             True       NaN
# 3      151701414.39766    151701414.39766            False       NaN
# 4    53652766196.00000  99988240531.00000            False       NaN
# 5    24018412140.27638  24018412140.27638            False       NaN
# 6      422396844.01063    562465341.71522             True       NaN
# 7    35270789767.42500  36350273102.30800            False       NaN
# 8   141825816383.70526 141825816383.70526             True       NaN
# 9    88673717334.78125  88673741439.88318             True       NaN
# 10    9250379771.02586  10000000000.00000            False       NaN
# 11    3431892087.62000   5047558528.00000             True       NaN
# 12     556849970.45279   1000000000.00000            False       NaN
# 13    1252814469.20926   1377546322.17313             True       NaN
# 14     355446510.24335    432822690.24335            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                 71659659264.00000          7554899138.12867
# 10        11                               NaN                       NaN
# 11        12                  3414166606.00000          8008669754.77718
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-11-14T13:23:00.000Z      36455.01531     19130088840.24089
# 1       None  2023-11-14T13:23:00.000Z       2036.18353     13223656937.32219
# 2       None  2023-11-14T13:22:00.000Z          1.00026     45200914043.99983
# 3       None  2023-11-14T13:22:00.000Z        244.06492       904297207.42128
# 4       None  2023-11-14T13:23:00.000Z          0.65439      3443819630.50619
# 5       None  2023-11-14T13:23:00.000Z          1.00010      5593350889.53195
# 6       None  2023-11-14T13:23:00.000Z         53.26266      2981853041.23490
# 7       None  2023-11-14T13:22:00.000Z          0.36036       415797806.88121
# 8       None  2023-11-14T13:23:00.000Z          0.07383       729541219.06150
# 9       None  2023-11-14T13:22:00.000Z          0.10543       275269446.42885
# 10      None  2023-11-14T13:22:00.000Z          0.93490      1260445739.27402
# 11      None  2023-11-14T13:23:00.000Z          2.34572        43321802.42726
# 12      None  2023-11-14T13:22:00.000Z         14.33387       851874850.60367
# 13      None  2023-11-14T13:22:00.000Z          5.32223       290908951.78469
# 14      None  2023-11-14T13:22:00.000Z         16.88206       755689924.70291
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      32.91510                      0.29450
# 1                      35.32500                      0.01305
# 2                      22.20220                     -0.01083
# 3                      18.35170                     -0.21428
# 4                     235.40810                      0.32308
# 5                      31.97870                     -0.00750
# 6                      28.01510                      0.95588
# 7                      12.60370                      0.94624
# 8                      11.82570                      0.44421
# 9                       3.75120                      0.10066
# 10                     33.69250                     -0.77660
# 11                    -26.20760                      0.30441
# 12                     10.43730                      0.32765
# 13                     -9.19390                      0.47524
# 14                    -14.39130                      0.64538
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -1.13118                      4.86361
# 1                       -0.85873                      8.44754
# 2                       -0.00899                     -0.03361
# 3                       -0.56521                     -1.68703
# 4                        0.44299                     -4.80106
# 5                        0.00723                     -0.00424
# 6                       -6.71731                     26.78940
# 7                       -2.11181                      3.66716
# 8                       -4.90391                      0.19982
# 9                       -4.02765                      8.87871
# 10                       7.35806                     30.69218
# 11                      -3.42310                     -2.35668
# 12                      -5.28599                     11.37643
# 13                      -4.39505                      8.39087
# 14                      -2.30634                     32.71109
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       35.56491                      37.95580
# 1                       30.90962                      25.50425
# 2                        0.03068                       0.01249
# 3                       17.03282                      15.03215
# 4                       34.39864                      32.54670
# 5                       -0.00835                      -0.01006
# 6                      143.77183                     180.86972
# 7                       46.23074                      44.49719
# 8                       24.66433                      19.53664
# 9                       23.25911                      25.32651
# 10                      81.37554                      80.18737
# 11                      21.66237                      20.57770
# 12                      94.99783                     133.81446
# 13                      41.93501                      30.13009
# 14                      85.23794                      81.38909
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       25.33849    712406388116.04871
# 1                       11.87542    244866770438.06158
# 2                        0.14690     87099868722.55002
# 3                        4.56089     37024993784.69110
# 4                       10.08039     35109632786.63382
# 5                        0.00829     24020719785.76377
# 6                      129.79879     22497978622.52517
# 7                       31.41818     12710357635.86478
# 8                        6.46732     10470677195.88559
# 9                       39.04012      9348648842.98656
# 10                      50.11516      8648198091.09437
# 11                      62.44752      8050248724.08977
# 12                     108.54591      7981814483.99785
# 13                      12.13215      6667770121.47701
# 14                      46.49924      6000668451.74533
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         51.20420                  765555321496.02002
# 1                         17.59680                  244866770438.06000
# 2                          6.25880                   90647170506.13000
# 3                          2.66060                   37024993784.69000
# 4                          2.52310                   65438625584.33000
# 5                          1.72620                   24020719785.76000
# 6                          1.61680                   29958399105.61000
# 7                          0.91330                   16216424338.25000
# 8                          0.75280                   10470677195.89000
# 9                          0.67180                    9348651384.33000
# 10                         0.62150                    9349019505.32000
# 11                         0.57850                   11840145483.12000
# 12                         0.57360                   14333868918.96000
# 13                         0.47920                    7331622066.70000
# 14                         0.43120                   12155081455.99000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-11-14T13:23:00.000Z          NaN           NaN
# 1           None  2023-11-14T13:23:00.000Z          NaN           NaN
# 2           None  2023-11-14T13:22:00.000Z   1027.00000      Ethereum
# 3           None  2023-11-14T13:22:00.000Z          NaN           NaN
# 4           None  2023-11-14T13:23:00.000Z          NaN           NaN
# 5           None  2023-11-14T13:23:00.000Z   1027.00000      Ethereum
# 6           None  2023-11-14T13:23:00.000Z          NaN           NaN
# 7           None  2023-11-14T13:22:00.000Z          NaN           NaN
# 8           None  2023-11-14T13:23:00.000Z          NaN           NaN
# 9           None  2023-11-14T13:22:00.000Z          NaN           NaN
# 10          None  2023-11-14T13:22:00.000Z          NaN           NaN
# 11          None  2023-11-14T13:23:00.000Z          NaN           NaN
# 12          None  2023-11-14T13:22:00.000Z   1027.00000      Ethereum
# 13          None  2023-11-14T13:22:00.000Z          NaN           NaN
# 14          None  2023-11-14T13:22:00.000Z          NaN           NaN
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 13             NaN           NaN                                         NaN
# 14             NaN           NaN                                         NaN
#
#                     timestamp
# 0  2023-11-14 16:34:12.151989
# 1  2023-11-14 16:34:12.151989
# 2  2023-11-14 16:34:12.151989
# 3  2023-11-14 16:34:12.151989
# 4  2023-11-14 16:34:12.151989
# 5  2023-11-14 16:34:12.151989
# 6  2023-11-14 16:34:12.151989
# 7  2023-11-14 16:34:12.151989
# 8  2023-11-14 16:34:12.151989
# 9  2023-11-14 16:34:12.151989
# 10 2023-11-14 16:34:12.151989
# 11 2023-11-14 16:34:12.151989
# 12 2023-11-14 16:34:12.151989
# 13 2023-11-14 16:34:12.151989
# 14 2023-11-14 16:34:12.151989

# %% [markdown]
# ### Defining the process of pulling data from API and normalizing it as 'api_runner'

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '846ab453-f4e2-4d5f-823a-7f152027c87b',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    


    
  
    df = pd.json_normalize(data['data'])    
    df['timestamp'] = pd.to_datetime('now')
    df
    
# automating data pull to csv file everytime data is updated
    if not os.path.isfile(r'C:\Users\use\Documents\Python Project Docs\Web_Scraping\Automating Crypto Website Scraping/API.csv'):
        df.to_csv(r'C:\Users\use\Documents\Python Project Docs\Web_Scraping\Automating Crypto Website Scraping/API.csv', header='column_names')
    else:
         df.to_csv(r'C:\Users\use\Documents\Python Project Docs\Web_Scraping\Automating Crypto Website Scraping/API.csv', mode='a', header=False)

# %% [markdown]
# ### Creating script to automate pulling of API data, normalizing the data, and saving it into a dataframe we can use

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed successfully')
    sleep(60) #sleep for 1 minute
exit()
# Out:
# API Runner completed successfully
# API Runner completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 8
#       6     api_runner()
#       7     print('API Runner completed successfully')
# ----> 8     sleep(60) #sleep for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Reading csv with data in

# %%
df4 = pd.read_csv(r'C:\Users\use\Documents\Python Project Docs\Web_Scraping\Automating Crypto Website Scraping/API.csv')

# %% [markdown]
# ## Transforming the data for analysis

# %%
# changing the format in which the numeric values in the dataset are displayed

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# grouping the data by the crypto currency name and the mean of the percentage changes across certain time periods

df5 = df4.groupby('name', sort=False)[['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()
df5
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.25887                      -1.18072
# Ethereum                         0.03032                      -0.88283
# Tether USDt                     -0.00745                      -0.00812
# BNB                             -0.05892                      -0.45439
# XRP                              0.32421                       0.44056
# USDC                            -0.01279                       0.00513
# Solana                           0.98396                      -6.70147
# Cardano                          1.17633                      -1.94513
# Dogecoin                         0.44510                      -4.90426
# TRON                             0.13266                      -4.01151
# Polygon                         -0.33121                       7.64601
# Toncoin                          0.31318                      -3.41723
# Chainlink                        0.53548                      -5.12417
# Polkadot                         0.64926                      -4.32463
# Avalanche                        1.04438                      -2.09039
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          4.81032                      35.52718
# Ethereum                         8.41142                      30.89010
# Tether USDt                     -0.02177                       0.02798
# BNB                             -1.59332                      17.13378
# XRP                             -4.80505                      34.37615
# USDC                            -0.00938                      -0.00804
# Solana                          26.77117                     143.77787
# Cardano                          3.81508                      46.38414
# Dogecoin                         0.20076                      24.66994
# TRON                             8.90286                      23.26446
# Polygon                         30.98345                      81.72699
# Toncoin                         -2.35768                      21.63981
# Chainlink                       11.65039                      95.25654
# Polkadot                         8.48764                      41.98826
# Avalanche                       32.98921                      85.54065
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          37.91453                      25.29741
# Ethereum                         25.48561                      11.85671
# Tether USDt                       0.01826                       0.15028
# BNB                              15.13076                       4.61855
# XRP                              32.53883                      10.07237
# USDC                             -0.01401                       0.00250
# Solana                          180.86471                     129.76369
# Cardano                          44.64360                      31.52248
# Dogecoin                         19.53412                       6.46276
# TRON                             25.37146                      39.01671
# Polygon                          80.59227                      50.35226
# Toncoin                          20.55531                      62.42477
# Chainlink                       134.17546                     108.75028
# Polkadot                         30.22028                      12.13443
# Avalanche                        81.73219                      46.66552

# %%
# pivoting the columns to rows for better visualization

df6 = df5.stack()
df6
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.25887
#              quote.USD.percent_change_24h    -1.18072
#              quote.USD.percent_change_7d      4.81032
#              quote.USD.percent_change_30d    35.52718
#              quote.USD.percent_change_60d    37.91453
#              quote.USD.percent_change_90d    25.29741
# Ethereum     quote.USD.percent_change_1h      0.03032
#              quote.USD.percent_change_24h    -0.88283
#              quote.USD.percent_change_7d      8.41142
#              quote.USD.percent_change_30d    30.89010
#              quote.USD.percent_change_60d    25.48561
#              quote.USD.percent_change_90d    11.85671
# Tether USDt  quote.USD.percent_change_1h     -0.00745
#              quote.USD.percent_change_24h    -0.00812
#              quote.USD.percent_change_7d     -0.02177
#              quote.USD.percent_change_30d     0.02798
#              quote.USD.percent_change_60d     0.01826
#              quote.USD.percent_change_90d     0.15028
# BNB          quote.USD.percent_change_1h     -0.05892
#              quote.USD.percent_change_24h    -0.45439
#              quote.USD.percent_change_7d     -1.59332
#              quote.USD.percent_change_30d    17.13378
#              quote.USD.percent_change_60d    15.13076
#              quote.USD.percent_change_90d     4.61855
# XRP          quote.USD.percent_change_1h      0.32421
#              quote.USD.percent_change_24h     0.44056
#              quote.USD.percent_change_7d     -4.80505
#              quote.USD.percent_change_30d    34.37615
#              quote.USD.percent_change_60d    32.53883
#              quote.USD.percent_change_90d    10.07237
# USDC         quote.USD.percent_change_1h     -0.01279
#              quote.USD.percent_change_24h     0.00513
#              quote.USD.percent_change_7d     -0.00938
#              quote.USD.percent_change_30d    -0.00804
#              quote.USD.percent_change_60d    -0.01401
#              quote.USD.percent_change_90d     0.00250
# Solana       quote.USD.percent_change_1h      0.98396
#              quote.USD.percent_change_24h    -6.70147
#              quote.USD.percent_change_7d     26.77117
#              quote.USD.percent_change_30d   143.77787
#              quote.USD.percent_change_60d   180.86471
#              quote.USD.percent_change_90d   129.76369
# Cardano      quote.USD.percent_change_1h      1.17633
#              quote.USD.percent_change_24h    -1.94513
#              quote.USD.percent_change_7d      3.81508
#              quote.USD.percent_change_30d    46.38414
#              quote.USD.percent_change_60d    44.64360
#              quote.USD.percent_change_90d    31.52248
# Dogecoin     quote.USD.percent_change_1h      0.44510
#              quote.USD.percent_change_24h    -4.90426
#              quote.USD.percent_change_7d      0.20076
#              quote.USD.percent_change_30d    24.66994
#              quote.USD.percent_change_60d    19.53412
#              quote.USD.percent_change_90d     6.46276
# TRON         quote.USD.percent_change_1h      0.13266
#              quote.USD.percent_change_24h    -4.01151
#              quote.USD.percent_change_7d      8.90286
#              quote.USD.percent_change_30d    23.26446
#              quote.USD.percent_change_60d    25.37146
#              quote.USD.percent_change_90d    39.01671
# Polygon      quote.USD.percent_change_1h     -0.33121
#              quote.USD.percent_change_24h     7.64601
#              quote.USD.percent_change_7d     30.98345
#              quote.USD.percent_change_30d    81.72699
#              quote.USD.percent_change_60d    80.59227
#              quote.USD.percent_change_90d    50.35226
# Toncoin      quote.USD.percent_change_1h      0.31318
#              quote.USD.percent_change_24h    -3.41723
#              quote.USD.percent_change_7d     -2.35768
#              quote.USD.percent_change_30d    21.63981
#              quote.USD.percent_change_60d    20.55531
#              quote.USD.percent_change_90d    62.42477
# Chainlink    quote.USD.percent_change_1h      0.53548
#              quote.USD.percent_change_24h    -5.12417
#              quote.USD.percent_change_7d     11.65039
#              quote.USD.percent_change_30d    95.25654
#              quote.USD.percent_change_60d   134.17546
#              quote.USD.percent_change_90d   108.75028
# Polkadot     quote.USD.percent_change_1h      0.64926
#              quote.USD.percent_change_24h    -4.32463
#              quote.USD.percent_change_7d      8.48764
#              quote.USD.percent_change_30d    41.98826
#              quote.USD.percent_change_60d    30.22028
#              quote.USD.percent_change_90d    12.13443
# Avalanche    quote.USD.percent_change_1h      1.04438
#              quote.USD.percent_change_24h    -2.09039
#              quote.USD.percent_change_7d     32.98921
#              quote.USD.percent_change_30d    85.54065
#              quote.USD.percent_change_60d    81.73219
#              quote.USD.percent_change_90d    46.66552
# dtype: float64

# %%
# using the stack() function changed the data format from a dataframe to a series
# we have to change it back in order to be able to continue using functions on the data

df7 = df6.to_frame(name='values')
df7
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.25887
#             quote.USD.percent_change_24h  -1.18072
#             quote.USD.percent_change_7d    4.81032
#             quote.USD.percent_change_30d  35.52718
#             quote.USD.percent_change_60d  37.91453
#             quote.USD.percent_change_90d  25.29741
# Ethereum    quote.USD.percent_change_1h    0.03032
#             quote.USD.percent_change_24h  -0.88283
#             quote.USD.percent_change_7d    8.41142
#             quote.USD.percent_change_30d  30.89010
#             quote.USD.percent_change_60d  25.48561
#             quote.USD.percent_change_90d  11.85671
# Tether USDt quote.USD.percent_change_1h   -0.00745
#             quote.USD.percent_change_24h  -0.00812
#             quote.USD.percent_change_7d   -0.02177
#             quote.USD.percent_change_30d   0.02798
#             quote.USD.percent_change_60d   0.01826
#             quote.USD.percent_change_90d   0.15028
# BNB         quote.USD.percent_change_1h   -0.05892
#             quote.USD.percent_change_24h  -0.45439
#             quote.USD.percent_change_7d   -1.59332
#             quote.USD.percent_change_30d  17.13378
#             quote.USD.percent_change_60d  15.13076
#             quote.USD.percent_change_90d   4.61855
# XRP         quote.USD.percent_change_1h    0.32421
#             quote.USD.percent_change_24h   0.44056
#             quote.USD.percent_change_7d   -4.80505
#             quote.USD.percent_change_30d  34.37615
#             quote.USD.percent_change_60d  32.53883
#             quote.USD.percent_change_90d  10.07237
# USDC        quote.USD.percent_change_1h   -0.01279
#             quote.USD.percent_change_24h   0.00513
#             quote.USD.percent_change_7d   -0.00938
#             quote.USD.percent_change_30d  -0.00804
#             quote.USD.percent_change_60d  -0.01401
#             quote.USD.percent_change_90d   0.00250
# Solana      quote.USD.percent_change_1h    0.98396
#             quote.USD.percent_change_24h  -6.70147
#             quote.USD.percent_change_7d   26.77117
#             quote.USD.percent_change_30d 143.77787
#             quote.USD.percent_change_60d 180.86471
#             quote.USD.percent_change_90d 129.76369
# Cardano     quote.USD.percent_change_1h    1.17633
#             quote.USD.percent_change_24h  -1.94513
#             quote.USD.percent_change_7d    3.81508
#             quote.USD.percent_change_30d  46.38414
#             quote.USD.percent_change_60d  44.64360
#             quote.USD.percent_change_90d  31.52248
# Dogecoin    quote.USD.percent_change_1h    0.44510
#             quote.USD.percent_change_24h  -4.90426
#             quote.USD.percent_change_7d    0.20076
#             quote.USD.percent_change_30d  24.66994
#             quote.USD.percent_change_60d  19.53412
#             quote.USD.percent_change_90d   6.46276
# TRON        quote.USD.percent_change_1h    0.13266
#             quote.USD.percent_change_24h  -4.01151
#             quote.USD.percent_change_7d    8.90286
#             quote.USD.percent_change_30d  23.26446
#             quote.USD.percent_change_60d  25.37146
#             quote.USD.percent_change_90d  39.01671
# Polygon     quote.USD.percent_change_1h   -0.33121
#             quote.USD.percent_change_24h   7.64601
#             quote.USD.percent_change_7d   30.98345
#             quote.USD.percent_change_30d  81.72699
#             quote.USD.percent_change_60d  80.59227
#             quote.USD.percent_change_90d  50.35226
# Toncoin     quote.USD.percent_change_1h    0.31318
#             quote.USD.percent_change_24h  -3.41723
#             quote.USD.percent_change_7d   -2.35768
#             quote.USD.percent_change_30d  21.63981
#             quote.USD.percent_change_60d  20.55531
#             quote.USD.percent_change_90d  62.42477
# Chainlink   quote.USD.percent_change_1h    0.53548
#             quote.USD.percent_change_24h  -5.12417
#             quote.USD.percent_change_7d   11.65039
#             quote.USD.percent_change_30d  95.25654
#             quote.USD.percent_change_60d 134.17546
#             quote.USD.percent_change_90d 108.75028
# Polkadot    quote.USD.percent_change_1h    0.64926
#             quote.USD.percent_change_24h  -4.32463
#             quote.USD.percent_change_7d    8.48764
#             quote.USD.percent_change_30d  41.98826
#             quote.USD.percent_change_60d  30.22028
#             quote.USD.percent_change_90d  12.13443
# Avalanche   quote.USD.percent_change_1h    1.04438
#             quote.USD.percent_change_24h  -2.09039
#             quote.USD.percent_change_7d   32.98921
#             quote.USD.percent_change_30d  85.54065
#             quote.USD.percent_change_60d  81.73219
#             quote.USD.percent_change_90d  46.66552

# %%
# resetting the index to useful format
df8 = df7.reset_index()

# %%
# changing column name from 'level_1' to 'percent_change'
df9 = df8.rename(columns={'level_1': 'percent_change'})

# %%
# changing values in 'percent_change' column to better visualize

df9['percent_change'] = df9['percent_change'].replace(['quote.USD.percent_change_1h', 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'], ['1h', '24h', '7d', '30d', '60d', '90d'])

# %% [markdown]
# ## Visualizing the data

# %% [markdown]
# ### Importing libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# using df9 as the final dataframe 
# creating a catplot

sns.catplot(x='percent_change', y='values', hue='name', data=df9, kind='point')
# Out:
# C:\Users\use\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# The purpose of this project was to showcase the automation of the process of pulling data from an API and normalizing the data
# We further performed a few high-level cleaning and exploration of the data, with one simple visualization at the end

# %% [markdown]
# # END
